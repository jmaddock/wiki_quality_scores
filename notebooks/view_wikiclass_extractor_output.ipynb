# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/klogg/dev/wiki_languages/quality_scores/test.csv',warn_bad_lines=True,error_bad_lines=False,index_col=None)
# Out:
# b'Skipping line 3423816: expected 12 fields, saw 15\n'

# %%
df.loc[df['project'] != 'None']
# Out:
#                                                            page_id  \
# <module 'uuid' from '/Library/Frameworks/Python... 3822          1
#                                                    3822          1
#                                                    59658         1
#                                                    99055         1
#                                                    102119        1
#                                                    116879        1
#                                                    123566        1
#                                                    151278        1
#                                                    305265        1
#                                                    366597        1
#                                                    370324        1
#                                                    443223        1
#
#                                                                                namespace  \
# ...

# %%
df1 = df.reset_index()

# %%
df1.loc[df1['level_1'] == 151278]
# Out:
#                                                    level_0  level_1  page_id  \
# 2231544  <module 'uuid' from '/Library/Frameworks/Pytho...   151278        1
# 2231545  <module 'uuid' from '/Library/Frameworks/Pytho...   151278        1
# 2231546  <module 'uuid' from '/Library/Frameworks/Pytho...   151278        1
#
#         namespace  title archive       user_text user_id revert  \
# 2231544     Tiger  Tiger    None       RyanCross   19514  False
# 2231545     Tiger  Tiger    None   70.166.103.18    None  False
# 2231546     Tiger  Tiger    None  161.53.192.162    None   True
#
#                           ts  \
# 2231544  2009-01-01 20:25:01
# 2231545  2009-04-17 13:25:02
# 2231546  2009-05-18 20:21:56
#
#                                                    project  quality
# 2231544                                               None      NaN
# 2231545  [('biography', 'ga'), ('usp-article', 'ga'), (...      NaN
# 2231546                                               None      NaN
